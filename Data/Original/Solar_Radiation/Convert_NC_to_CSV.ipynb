# %%
# pip install xarray netcdf4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xarray as xr
import pandas as pd

# --- Set Up ---
netcdf_file_in = "C:/Users/12256/OneDrive - University of North Carolina at Chapel Hill/Desktop/Cool Pavements/Data/Orig/Irradiance/CERES_FLASH_TISA_Version1A_Subset_20250701-20251205.nc"
csv_file_out = 'C:/Users/12256/OneDrive - University of North Carolina at Chapel Hill/Desktop/Cool Pavements/Data/Orig/Irradiance/CERES_FLASH_TISA_Version1A_Subset_20250701-20251205.csv'

# 1. Open the NetCDF file
ds = xr.open_dataset(netcdf_file_in)

# 2. Convert to a pandas DataFrame (can select specific variables)
# Example: df = ds[['temperature', 'latitude', 'longitude']].to_dataframe()
df = ds.to_dataframe()

# 3. Clean up (optional: remove rows with missing data)
# df_cleaned = df.dropna()

# 4. Write to CSV
df.to_csv(csv_file_out)
